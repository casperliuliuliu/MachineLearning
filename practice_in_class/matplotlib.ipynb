# %%
import matplotlib.pyplot as plt 
# %matplotlib inline
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'ro',ls = ":") 
plt.ylabel('y label')
plt.xlabel('x label')
#plt.show()
# Out:
# Text(0.5, 0, 'x label')

# %%
X1 = ['Failed', '60‐69', '70‐79', '80‐89', '90‐99', '100'] 
Y1 = [11, 3, 7, 8, 1, 5] 
Z1 = [1,2,3,4,5,6]
plt.ylabel('count')
plt.xlabel('score')
plt.bar(X1, Y1)
plt.bar(X1, Z1)
plt.title('Final Exam Score Table')
#plt.show()
# Out:
# Text(0.5, 1.0, 'Final Exam Score Table')
